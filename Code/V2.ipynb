# %%
import pandas as pd
import re
import csv
import seaborn as sns
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from textblob import Word
import nltk
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import warnings
from collections import Counter
import itertools
import string
from pythainlp.corpus import thai_stopwords
from pythainlp import word_tokenize
import re
import string
import pythainlp
from nltk.corpus import wordnet
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv ('data_tag/datatestv5.2.csv')

# %%
data = pd.read_csv ('data_tag/datatestv5.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14541 entries, 0 to 14540
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Job_Title         14541 non-null  object
#  1   Company           14541 non-null  object
#  2   Location          14541 non-null  object
#  3   Job_Position      14541 non-null  object
#  4   Job_Type          14541 non-null  object
#  5   Salary Min        1894 non-null   float64
#  6   Salary Max        1894 non-null   float64
#  7   Job_Description   14541 non-null  object
#  8   Tag               14541 non-null  object
#  9   Language          14541 non-null  object
#  10  R_sentence_count  14541 non-null  int64
#  11  R_word_count      14541 non-null  int64
#  12  R_char_count      14541 non-null  int64
#  13  R_punc_count      14541 non-null  int64
# dtypes: float64(2), int64(4), object(8)
# memory usage: 1.6+ MB

# %%
from collections import Counter
import re

# A predefined set of skills for demonstration
skills_list = ["accounting", "management", "excel", "communication", "leadership", 
               "programming", "Python", "C++", "project management", "marketing", 
               "data analysis", "machine learning"]

# Function for cleaning text
def clean_text(text):
    # Remove HTML tags and non-alphabetic characters
    text = re.sub(r'<.*?>', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text)
    # Convert text to lowercase
    text = text.lower()
    return text

# Function to extract skills
def extract_skills(text, skills_list):
    # Split the text into words
    words = text.split()
    # Find skills in the text
    extracted_skills = [skill for skill in skills_list if skill.lower() in words]
    return extracted_skills

# Apply text cleaning and skill extraction
data['Cleaned_Job_Description'] = data['Job_Description'].apply(clean_text)
data['Extracted_Skills'] = data['Cleaned_Job_Description'].apply(lambda x: extract_skills(x, skills_list))

# Display the first few rows with the extracted skills
data[['Job_Description', 'Cleaned_Job_Description', 'Extracted_Skills']].head()
# Out:
#                                      Job_Description  \
# 0  About us ร่วมเป็นส่วนหนึ่งกับทีม MEGA CLINIC\n...
# 1  Position Summary This position is for a lawyer...
# 2  Reports To: FINANCE MANAGER Key Result Areas: ...
# 3  Job Description Prepare management reports for...
# 4  Job Description: The ideal candidate will be a...
#
#                              Cleaned_Job_Description  \
# 0  about us  mega clinic\nmega clinic \n\n mega c...
# 1  position summary this position is for a lawyer...
# 2  reports to finance manager key result areas th...
# 3  job description prepare management reports for...
# 4  job description the ideal candidate will be as...
#
#                               Extracted_Skills
# 0                                           []
# 1                                 [management]
# 2      [accounting, management, communication]
# 3  [accounting, management, excel, leadership]
# 4          [accounting, management, marketing]

# %%
df['Job_Description'] = df['Job_Description'].apply(lambda x : re.sub('\\\n',' ', x))
df['R_word_count'] = df['Job_Description'].apply(lambda x : len(x.split()))
df['R_char_count'] = df['Job_Description'].apply(lambda x : len(x.replace(' ','')))
df['R_punc_count'] = df['Job_Description'].apply(lambda x : len([a for a in x if a in string.punctuation]))
                                                           
df_stats_raw = df[['Job_Position','R_word_count','R_char_count','R_punc_count']]
df_stats_raw
# Out:
#                                          Job_Position  R_word_count  \
# 0                    Financial Accounting & Reporting           108
# 1                                            Taxation           513
# 2                  Accounts Receivable/Credit Control           269
# 3              Business Services & Corporate Advisory           262
# 4                                            Taxation           264
# ...                                               ...           ...
# 14536                        Food Technology & Safety           184
# 14537                        Food Technology & Safety            89
# 14538  Mathematics, Statistics & Information Sciences           504
# 14539                        Food Technology & Safety           365
# 14540                        Biotechnology & Genetics             1
#
#        R_char_count  R_punc_count
# 0              1490            27
# 1              2969            99
# 2              1579            12
# 3              1531            17
# 4              1523            28
# ...             ...           ...
# 14536          1053            46
# 14537          1327            13
# 14538          3039            88
# 14539          2319            88
# 14540            39             0
#
# [14541 rows x 4 columns]

# %%
# Function to count sentences, handling Thai and English
def count_sentences(text):
    sentences = re.split(r"(?<=[.!?])\s+", text)  # Split on punctuation followed by whitespace
    thai_sentences = pythainlp.tokenize.sent_tokenize(text)  # Tokenize Thai sentences
    return len(sentences) + len(thai_sentences) - max(len(sentences), len(thai_sentences))  # Avoid double-counting

# Apply the sentence count function and other calculations
df['Job_Description'] = df['Job_Description'].apply(lambda x: re.sub('\\\n', ' ', x))  # Remove newlines
df['R_sentence_count'] = df['Job_Description'].apply(count_sentences)  # Count sentences
df['R_word_count'] = df['Job_Description'].apply(lambda x: len(x.split()))  # Count words
df['R_char_count'] = df['Job_Description'].apply(lambda x: len(x.replace(' ', '')))  # Count characters
df['R_punc_count'] = df['Job_Description'].apply(lambda x: len([a for a in x if a in string.punctuation]))  # Count punctuation

df_stats_raw = df[['Job_Position', 'R_sentence_count', 'R_word_count', 'R_char_count', 'R_punc_count']]

# %%
df_stats_raw
# Out:
#                                          Job_Position  R_sentence_count  \
# 0                    Financial Accounting & Reporting                 9
# 1                                            Taxation                 7
# 2                  Accounts Receivable/Credit Control                 1
# 3              Business Services & Corporate Advisory                 1
# 4                                            Taxation                 3
# ...                                               ...               ...
# 14536                        Food Technology & Safety                 2
# 14537                        Food Technology & Safety                 2
# 14538  Mathematics, Statistics & Information Sciences                 5
# 14539                        Food Technology & Safety                 5
# 14540                        Biotechnology & Genetics                 1
#
#        R_word_count  R_char_count  R_punc_count
# 0               108          1490            27
# 1               513          2969            99
# 2               269          1579            12
# 3               262          1531            17
# 4               264          1523            28
# ...             ...           ...           ...
# 14536           184          1053            46
# 14537            89          1327            13
# 14538           504          3039            88
# 14539           365          2319            88
# 14540             1            39             0
#
# [14541 rows x 5 columns]

# %%
df
# Out:
#                                                Job_Title  \
# 0                           GL Account Assistant Manager
# 1                                          Tax Associate
# 2      Accounts Receivable Supervisor/หัวหน้าหน่วยบัญ...
# 3                           Assistant Accounting Manager
# 4           Assistant Tax Manager - M&A and tax advisory
# ...                                                  ...
# 14536  Foodscience (RD/Production/QA/Marketing)/เจ้าห...
# 14537               Chef Specialist (Bakery)/เชฟเบเกอรี่
# 14538                 Data Engineer – Advanced Analytics
# 14539       R&D Manager/ผู้จัดการ วิจัยและพัฒนาผลิตภัณฑ์
# 14540         Senior Researcher ประจำสำนักงานรังสิต สวทช
#
#                                                  Company      Location  \
# 0                                  MEGA CLINIC Co., Ltd.       Bangkok
# 1                        PKF Holdings (Thailand) Limited       Bangkok
# 2                        Sodexo Services (Thailand) Ltd.       Bangkok
# 3                         Mazars Holding (Thailand) Ltd.       Bangkok
# 4                         Mazars Holding (Thailand) Ltd.       Bangkok
# ...                                                  ...           ...
# 14536             C.P. RETAILING AND MARKETING CO., LTD.  Pathum Thani
# 14537   Rich Products Manufacturing (Thailand) Co., Ltd.       Bangkok
# 14538                          Hanesbrands ROH Asia Ltd.       Bangkok
# 14539                      Tyson International APAC Ltd.  Samut Prakan
# 14540  S&J International Enterprises Public Company L...  Pathum Thani
#
#                                          Job_Position   Job_Type  Salary Min  \
# 0                    Financial Accounting & Reporting  Full time     36000.0
# 1                                            Taxation  Full time         NaN
# 2                  Accounts Receivable/Credit Control  Full time         NaN
# 3              Business Services & Corporate Advisory  Full time         NaN
# 4                                            Taxation  Full time         NaN
# ...                                               ...        ...         ...
# 14536                        Food Technology & Safety  Full time         NaN
# 14537                        Food Technology & Safety  Full time         NaN
# 14538  Mathematics, Statistics & Information Sciences  Full time         NaN
# 14539                        Food Technology & Safety  Full time         NaN
# 14540                        Biotechnology & Genetics  Full time         NaN
#
#        Salary Max                                    Job_Description  \
# 0         53000.0  u ร่วมเป็นส่วนหนึ่งกับทีม mega clinic mega cli...
# 1             NaN  position summary position lawyer assist client...
# 2             NaN  report finance manager key result area positio...
# 3             NaN  job description prepare management report use ...
# 4             NaN  job description ideal candidate assigned work ...
# ...           ...                                                ...
# 14536         NaN  bachelor degree science program food science t...
# 14537         NaN  หน้าที่รับผิดชอบ ให้คำแนะนำเกี่ยวกับเบเกอรี่ แ...
# 14538         NaN  overview hanesbrands inc leading apparel compa...
# 14539         NaN  purpose research development manager position ...
# 14540         NaN            วิจัยค้นคว้านวัตกรรมทางด้านเครื่องสำอาง
#
#                         Tag Language  R_sentence_count  R_word_count  \
# 0                Accounting       th                 9           108
# 1                Accounting       en                 7           513
# 2                Accounting       en                 1           269
# 3                Accounting       en                 1           262
# 4                Accounting       en                 3           264
# ...                     ...      ...               ...           ...
# 14536  Science & Technology       en                 2           184
# 14537  Science & Technology       th                 2            89
# 14538  Science & Technology       en                 5           504
# 14539  Science & Technology       en                 5           365
# 14540  Science & Technology       th                 1             1
#
#        R_char_count  R_punc_count  \
# 0              1490            27
# 1              2969            99
# 2              1579            12
# 3              1531            17
# 4              1523            28
# ...             ...           ...
# 14536          1053            46
# 14537          1327            13
# 14538          3039            88
# 14539          2319            88
# 14540            39             0
#
#                                  Job_Description_Cleaned  C_sentence_count  \
# 0      u ร่วมเป็นส่วนหนึ่งกับทีม mega clinic mega cli...                 1
# 1      position summary position lawyer assist client...                 1
# 2      report finance manager key result area positio...                 1
# 3      job description prepare management report use ...                 1
# 4      job description ideal candidate assigned work ...                 1
# ...                                                  ...               ...
# 14536  bachelor degree science program food science t...                 1
# 14537  หน้าที่รับผิดชอบ ให้คำแนะนำเกี่ยวกับเบเกอรี่ แ...                 1
# 14538  overview hanesbrands inc leading apparel compa...                 1
# 14539  purpose research development manager position ...                 1
# 14540            วิจัยค้นคว้านวัตกรรมทางด้านเครื่องสำอาง                 1
#
#        C_word_count  C_char_count  C_punc_count
# 0                90          1404             0
# 1               341          2264             0
# 2               190          1306             0
# 3               174          1249             0
# 4               178          1234             0
# ...             ...           ...           ...
# 14536           115           818             0
# 14537            82          1279             0
# 14538           342          2445             0
# 14539           269          1898             0
# 14540             1            39             0
#
# [14541 rows x 19 columns]

# %%
df['Job_Description_Cleaned'] = df['Job_Description']

# %%
## Lower case
df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].apply(lambda x: " ".join(x.lower() for x in x.split()))

## Remove tabulation, punctuation and handle Thai characters
df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].str.replace('[^\w\sก-๙]', ' ', regex=True)

## Digits
df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].str.replace('\d+', '', regex=True)

## Remove stop words (English and Thai)
stop_words = set(stopwords.words('english')).union(set(thai_stopwords()))
df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

## English Lemmatization
df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

## Tokenization for Thai Language (if needed)
# df['Job_description_cleaned'] = df['Job_description_cleaned'].apply(lambda x: " ".join(word_tokenize(x, engine='newmm')))

print("Preprocessed data: \n")
df.head()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Tokyo\AppData\Local\Temp\ipykernel_12624\2863076896.py:5: SyntaxWarning: invalid escape sequence '\w'
#   df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].str.replace('[^\w\sก-๙]', ' ', regex=True)
# C:\Users\Tokyo\AppData\Local\Temp\ipykernel_12624\2863076896.py:8: SyntaxWarning: invalid escape sequence '\d'
#   df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].str.replace('\d+', '', regex=True)
# Preprocessed data:
#                                            Job_Title  \
# 0                       GL Account Assistant Manager
# 1                                      Tax Associate
# 2  Accounts Receivable Supervisor/หัวหน้าหน่วยบัญ...
# 3                       Assistant Accounting Manager
# 4       Assistant Tax Manager - M&A and tax advisory
#
#                            Company Location  \
# 0            MEGA CLINIC Co., Ltd.  Bangkok
# 1  PKF Holdings (Thailand) Limited  Bangkok
# 2  Sodexo Services (Thailand) Ltd.  Bangkok
# 3   Mazars Holding (Thailand) Ltd.  Bangkok
# 4   Mazars Holding (Thailand) Ltd.  Bangkok
#
#                              Job_Position   Job_Type  Salary Min  Salary Max  \
# 0        Financial Accounting & Reporting  Full time     36000.0     53000.0
# 1                                Taxation  Full time         NaN         NaN
# 2      Accounts Receivable/Credit Control  Full time         NaN         NaN
# 3  Business Services & Corporate Advisory  Full time         NaN         NaN
# 4                                Taxation  Full time         NaN         NaN
#
#                                      Job_Description         Tag Language  \
# 0  About us ร่วมเป็นส่วนหนึ่งกับทีม MEGA CLINIC M...  Accounting       th
# 1  Position Summary This position is for a lawyer...  Accounting       en
# 2  Reports To: FINANCE MANAGER Key Result Areas: ...  Accounting       en
# 3  Job Description Prepare management reports for...  Accounting       en
# 4  Job Description: The ideal candidate will be a...  Accounting       en
#
#    R_sentence_count  R_word_count  R_char_count  R_punc_count  \
# 0                 9           108          1490            27
# 1                 7           513          2969            99
# 2                 1           269          1579            12
# 3                 1           262          1531            17
# 4                 3           264          1523            28
#
#                              Job_Description_Cleaned
# 0  u ร่วมเป็นส่วนหนึ่งกับทีม mega clinic mega cli...
# 1  position summary position lawyer assist client...
# 2  report finance manager key result area positio...
# 3  job description prepare management report use ...
# 4  job description ideal candidate assigned work ...

# %%
df.to_csv(f'data_tag/datatestv5.2.csv',index=False)

# %%
## Remove stop words (English, Thai, and Custom)
stop_words = set(stopwords.words('english')).union(set(thai_stopwords()))
df['Job_Description_Cleaned'] = df['Job_Description_Cleaned'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

# %%
df['Job_Description'] = df['Job_Description_Cleaned'].apply(lambda x : re.sub('\\\n',' ', x))
df['C_sentence_count'] = df['Job_Description_Cleaned'].apply(count_sentences) 
df['C_word_count'] = df['Job_Description_Cleaned'].apply(lambda x : len(x.split()))
df['C_char_count'] = df['Job_Description_Cleaned'].apply(lambda x : len(x.replace(' ','')))
df['C_punc_count'] = df['Job_Description_Cleaned'].apply(lambda x : len([a for a in x if a in string.punctuation]))

df_stats_clean = df[['Job_Position','C_sentence_count','C_word_count','C_char_count','C_punc_count']]
df_stats_clean
# Out:
#                                          Job_Position  C_sentence_count  \
# 0                    Financial Accounting & Reporting                 1
# 1                                            Taxation                 1
# 2                  Accounts Receivable/Credit Control                 1
# 3              Business Services & Corporate Advisory                 1
# 4                                            Taxation                 1
# ...                                               ...               ...
# 14536                        Food Technology & Safety                 1
# 14537                        Food Technology & Safety                 1
# 14538  Mathematics, Statistics & Information Sciences                 1
# 14539                        Food Technology & Safety                 1
# 14540                        Biotechnology & Genetics                 1
#
#        C_word_count  C_char_count  C_punc_count
# 0                90          1404             0
# 1               341          2264             0
# 2               190          1306             0
# 3               174          1249             0
# 4               178          1234             0
# ...             ...           ...           ...
# 14536           115           818             0
# 14537            82          1279             0
# 14538           342          2445             0
# 14539           269          1898             0
# 14540             1            39             0
#
# [14541 rows x 5 columns]

# %%
descriptions = ''.join(d for d in df['Job_Description_Cleaned']) #Looping over all cells in Job Description column and joining then together
print ('There are {} words in the combined data-related job descriptions.'.format(len(descriptions))) #Printing results
# Out:
# There are 20401035 words in the combined data-related job descriptions.

# %%
word_count = dict(Counter(descriptions.split()))
print('Without ranking the first 10 words look like: {}'.format(dict(itertools.islice(word_count.items(), 10))))
# Out:
# Without ranking the first 10 words look like: {'u': 4344, 'ร่วมเป็นส่วนหนึ่งกับทีม': 1, 'mega': 27, 'clinic': 138, 'เป็นคลินิกเวชกรรมประเภทเสริมความงามที่มีมาตรฐานและการบริการระดับสากล': 1, 'ในปัจจุบัน': 5, 'มีสาขาทั้งหมด': 1, 'สาขา': 553, 'สยามสแควร์': 3, 'เซ็นทรัลลาดพร้าว': 2}

# %%
words_popular = {k: v for k, v in sorted(word_count.items(), key=lambda item: item[1], reverse=True)} 
print('With ranking the first 10 words look like: {}'.format(dict(itertools.islice(words_popular.items(), 10))))
# Out:
# With ranking the first 10 words look like: {'experience': 21500, 'team': 17488, 'business': 16630, 'skill': 15996, 'work': 15934, 'management': 14807, 'customer': 14793, 'sale': 12622, 'year': 11668, 'related': 11108}

# %%
words_all_jobs = pd.DataFrame.from_dict(words_popular, orient='index',columns=['Count']).reset_index() #(5) Create our cleaned dataframe
words_all_jobs.head(5)
# Out:
#         index  Count
# 0  experience  21500
# 1        team  17488
# 2    business  16630
# 3       skill  15996
# 4        work  15934

# %%
wordcloud = WordCloud(min_font_size=8, max_font_size=100, max_words=500, width=800, height=400,prefer_horizontal=1, background_color='#f2f6fa').generate_from_frequencies(words_popular) #Generate wordcloud class from dictionary

plt.imshow(wordcloud.recolor(), interpolation='bilinear')
plt.axis('off')
plt.show();

# %%
fig, ax = plt.subplots(figsize=(25, 10))
ax = sns.barplot(data=words_all_jobs[:50],x='index',y='Count')

for bar in ax.patches:
    if bar.get_x() < 4:
        bar.set_color('red')
plt.xticks(rotation=45, fontsize=8) 
plt.xlabel('Words', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.title('50 Most Frequently Used Words', fontsize=15, pad=20);
